# %%
# importing
import pandas as pd

# %%
# creating data
pd.DataFrame({'yes':[11,20],'no':[33,78]})
# Out:
#    yes  no
# 0   11  33
# 1   20  78

# %%
# dataframe entries arenot limited to integers
pd.DataFrame({'Prekshya':[' Are you hungry?','Lets,Grab a food.'],'Sanjita':['yeah,sure.','Sure, why not?']})
# Out:
#             Prekshya         Sanjita
# 0    Are you hungry?      yeah,sure.
# 1  Lets,Grab a food.  Sure, why not?

# %%
# using index parameter
pd.DataFrame({'Prekshya':[' Are you hungry?','Lets,Grab a food.'],'Sanjita':['yeah,sure.','Sure, why not?']},index = ['Product A','Product B'])
# Out:
#                     Prekshya         Sanjita
# Product A    Are you hungry?      yeah,sure.
# Product B  Lets,Grab a food.  Sure, why not?

# %%
# series
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([11,22,33],index =['2011 sales','2022 sales','2033 sales'],name = 'Poduct A')
# Out:
# 2011 sales    11
# 2022 sales    22
# 2033 sales    33
# Name: Poduct A, dtype: int64

# %%
# Reading data files
population_analysis = pd.read_csv("C:/Users/Prekshya/Desktop/world-population-analysis/data/Dataset.csv")

# %%
population_analysis.shape
# Out:
# (260, 11)

# %%
population_analysis.head()
# Out:
#    Serial Number Country Code Country Name       Area  Land Area  Water  Area  \
# 0              1           af  Afghanistan   652230.0   652230.0          0.0
# 1              2           al      Albania    28748.0    27398.0       1350.0
# 2              3           ag      Algeria  2381741.0  2381741.0          0.0
# 3              4           an      Andorra      468.0      468.0          0.0
# 4              5           ao       Angola  1246700.0  1246700.0          0.0
#
#    Population  Population Growth Rate  Birth Rate  Death Rate  Migration Rate
# 0  32564342.0                    2.32       38.57       13.89            1.51
# 1   3029278.0                    0.30       12.92        6.58            3.30
# 2  39542166.0                    1.84       23.67        4.31            0.92
# 3     85580.0                    0.12        8.13        6.96            0.00
# 4  19625353.0                    2.78       38.78       11.49            0.46

# %%
import pandas as pd
pd.Series([30,35,40], index = ['2015 sales','2020 sales','2025 sales'], name = 'Product A')
# Out:
# 2015 sales    30
# 2020 sales    35
# 2025 sales    40
# Name: Product A, dtype: int64
