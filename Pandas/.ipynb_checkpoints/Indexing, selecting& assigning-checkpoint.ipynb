# %%
import pandas as pd
population_analysis = pd.read_csv("C:/Users/Prekshya/Desktop/world-population-analysis/data/Dataset.csv")
pd.set_option('display.max_rows', 5)

# %%
population_analysis
# Out:
#      Serial Number Country Code    Country Name      Area  Land Area  \
# 0                1           af     Afghanistan  652230.0   652230.0
# 1                2           al         Albania   28748.0    27398.0
# ..             ...          ...             ...       ...        ...
# 258            259           zn   Pacific Ocean       NaN        NaN
# 259            260           oo  Southern Ocean       NaN        NaN
#
#      Water  Area  Population  Population Growth Rate  Birth Rate  Death Rate  \
# 0            0.0  32564342.0                    2.32       38.57       13.89
# 1         1350.0   3029278.0                    0.30       12.92        6.58
# ..           ...         ...                     ...         ...         ...
# 258          NaN         NaN                     NaN         NaN         NaN
# 259          NaN         NaN                     NaN         NaN         NaN
#
#      Migration Rate
# 0              1.51
# 1              3.30
# ..              ...
# ...

# %%
population_analysis.Area
# Out:
# 0      652230.0
# 1       28748.0
#          ...
# 258         NaN
# 259         NaN
# Name: Area, Length: 260, dtype: float64

# %%
population_analysis['Area']
# Out:
# 0      652230.0
# 1       28748.0
#          ...
# 258         NaN
# 259         NaN
# Name: Area, Length: 260, dtype: float64

# %%
population_analysis['Area'][0]
# Out:
# np.float64(652230.0)

# %%
population_analysis.iloc[0]
# Out:
# Serial Number         1
# Country Code         af
#                   ...
# Death Rate        13.89
# Migration Rate     1.51
# Name: 0, Length: 11, dtype: object

# %%
population_analysis.iloc[:,0]
# Out:
# 0        1
# 1        2
#       ...
# 258    259
# 259    260
# Name: Serial Number, Length: 260, dtype: int64

# %%
population_analysis.iloc[:3,0]
# Out:
# 0    1
# 1    2
# 2    3
# Name: Serial Number, dtype: int64

# %%
population_analysis.iloc[1:3,0]
# Out:
# 1    2
# 2    3
# Name: Serial Number, dtype: int64

# %%
population_analysis.iloc[[0,1,2],0]
# Out:
# 0    1
# 1    2
# 2    3
# Name: Serial Number, dtype: int64

# %%
population_analysis.iloc[-5:]
# Out:
#      Serial Number Country Code    Country Name  Area  Land Area  Water  Area  \
# 255            256           xq    Arctic Ocean   NaN        NaN          NaN
# 256            257           zh  Atlantic Ocean   NaN        NaN          NaN
# 257            258           xo    Indian Ocean   NaN        NaN          NaN
# 258            259           zn   Pacific Ocean   NaN        NaN          NaN
# 259            260           oo  Southern Ocean   NaN        NaN          NaN
#
#      Population  Population Growth Rate  Birth Rate  Death Rate  \
# 255         NaN                     NaN         NaN         NaN
# 256         NaN                     NaN         NaN         NaN
# 257         NaN                     NaN         NaN         NaN
# 258         NaN                     NaN         NaN         NaN
# 259         NaN                     NaN         NaN         NaN
#
#      Migration Rate
# 255             NaN
# 256             NaN
# 257             NaN
# 258             NaN
# ...

# %%
population_analysis.loc[0, 'Area']
# Out:
# np.float64(652230.0)

# %%
population_analysis.loc[:, ['Serial Number', 'Country Name', 'Area']]
# Out:
#      Serial Number    Country Name      Area
# 0                1     Afghanistan  652230.0
# 1                2         Albania   28748.0
# ..             ...             ...       ...
# 258            259   Pacific Ocean       NaN
# 259            260  Southern Ocean       NaN
#
# [260 rows x 3 columns]

# %%
population_analysis[population_analysis["Country Name"] == "Albania"]
# Out:
#    Serial Number Country Code Country Name     Area  Land Area  Water  Area  \
# 1              2           al      Albania  28748.0    27398.0       1350.0
#
#    Population  Population Growth Rate  Birth Rate  Death Rate  Migration Rate
# 1   3029278.0                     0.3       12.92        6.58             3.3

# %%
population_analysis.loc[
    (population_analysis["Country Name"] == "Albania") &
    (population_analysis["Population"] >= 90)
]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17804\197936206.py in ?()
# ----> 1 population_analysis.loc[([population_analysis["Country Name"] == "Albania"]) & (population_analysis.points >= 90)]
#
# E:\ANA\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'points'
