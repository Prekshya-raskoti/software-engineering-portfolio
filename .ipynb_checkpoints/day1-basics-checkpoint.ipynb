# %%
print("Day1 - starting my data science journey")
# Out:
# Day1 - starting my data science journey

# %%
name = "Prekshya"
age = 23
print(name,age)
# Out:
# Prekshya 23

# %%
numbers = [1,2,3,4,5]
for n in numbers:
    print(n * 2)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
def add_numbers(a,b):
    return a + b

print(add_numbers(7,4))
# Out:
# 11

# %%
print(7 - 9)
# Out:
# -2
