# %% [markdown]
# ## Python Practice Exercises
# These are practice exercises I am doing while learning
# Python for my MSc AI & Data Science preparation.
#
# ## Topics covered
# - Variables
# - Maths operators
# - Float vs Integer
# - Solving real world problems with Python

# %%
#variables and maths
# Q1 - Store your name and age in variables and print them
name = "Prekshya Raskoti"
age = 23
print("My name is", name,"and I am",age, "years old.") 
print(f"My name is {name} and i am {age} years old.")
# Out:
# My name is Prekshya Raskoti and I am 23 years old.
# My name is Prekshya Raskoti and i am 23 years old.

# %%
# Q2 - There are 7 days in a week and 52 weeks in a year
# Define days_per_week = 7
# Define weeks_per_year = 52
# Calculate days_per_year using those two variables
days_per_week = 7
weeks_per_year = 52
days_per_year = days_per_week * weeks_per_year
print(days_per_year)
# Out:
# 364

# %%
# Q3 - A shop sells 35 items per hour
# Define items_per_hour = 35
# Calculate items_per_day (shop open 8 hours)
# Calculate items_per_week
items_per_hour = 35
items_per_day = items_per_hour * 8
print(items_per_day)
items_per_week = items_per_hour * 8 * 7
print(items_per_week)
# Out:
# 280
# 1960

# %%
# Q4 - Define a variable speed_kmh = 60
# Calculate how far a car travels in 3.5 hours
# distance = speed * time
speed_kmh = 60
time = 3.5 
distance = speed_kmh * time
print(distance)
# Out:
# 210.0

# %%
# Q5 - A student reads 25 pages per day
# Calculate how many pages in a week
# Calculate how many pages in a month (30 days)
# Calculate how many pages in a year
pages_per_day = 25
pages_per_week = pages_per_day * 7
print(f"pages_per_week :{pages_per_week}")
pages_per_month = pages_per_day * 30
print(f"pages_per_month :{pages_per_month}")
pages_per_year = pages_per_day * 365
print(f"pages_per_year:{pages_per_year}")
# Out:
# pages_per_week :175
# pages_per_month :750
# pages_per_year:9125

# %%
#operators and types
# Q6 - What is the result and type of each?
print(10 / 3)   # <class'float'>
print(10 // 3)  # <class'int'>
print(10 % 3)   # <class'int'>
print(2 ** 8)   # <class'int'>
# Out:
# 3.3333333333333335
# 3
# 1
# 256

# %%
# Q7 - A cinema has 15 rows with 28 seats each
# Define rows = 15
# Define seats_per_row = 28
# Calculate total_seats
# Calculate remaining_seats if 247 people are seated
# Calculate percentage of seats filled (round to 2 decimal places)
# Q7 - Cinema seats
rows = 15
seats_per_row = 28
total_seats = rows * seats_per_row
print(f"Total seats: {total_seats}")

seated_people = 247
remaining_seats = total_seats - seated_people
print(f"Remaining seats: {remaining_seats}")

per_of_seats_filled = round((seated_people / total_seats) * 100, 2)
print(f"Percentage filled: {per_of_seats_filled}%")
# Out:
# Total seats: 420
# Remaining seats: 173
# Percentage filled: 58.81%

# %%
# Q8 - Temperature converter
# temp_celsius = 37
# Convert to Fahrenheit using formula: (celsius * 9/5) + 32
# Print the result
temp_celsius = 37
fahrenheit = (temp_celsius * 9 / 5) + 32
print(fahrenheit)
# Out:
# 98.6

# %%
# Q9 - A pizza is cut into 8 slices
# 3 people want equal shares
# How many full slices does each person get? (use //)
# How many slices are left over? (use %)
slices = 8
people = 3
each_share = slices // people
print(each_share)
remained_slices = slices % people
print(remained_slices)
# Out:
# 2
# 2

# %%
# Q10 - Define these variables
# principal = 10000 (money invested)
# rate = 0.05 (5% interest)
# time = 3 (years)
# Calculate simple interest = principal * rate * time
# Calculate total amount = principal + simple_interest
principal = 10000
rate = 0.05
time = 3
simple_interest = principal * rate * time
print(simple_interest)
total_amount = principal + simple_interest
print(total_amount)
# Out:
# 1500.0
# 11500.0

# %%
# Q11 - A factory runs 3 shifts per day
# Each shift is 8 hours
# Workers produce 47 items per hour per shift
# There are 12 workers per shift
# Calculate:
# hours_per_day
# items_per_shift
# items_per_day
# items_per_week
# items_per_year
shifts_per_day = 3
shift_hour = 8  
items_per_hour_shift = 47
total_workers = 12 

# 1. Hours per day
hours_per_day = shift_hour * shifts_per_day
print(f"Hours per day: {hours_per_day}")

# 2. Items per shift (Workers * Items/Hour * Hours)
items_per_shift = total_workers * items_per_hour_shift * shift_hour
print(f"Items per shift: {items_per_shift}")

# 3. Items per day (Items/Shift * Shifts)
items_per_day = items_per_shift * shifts_per_day
print(f"Items per day: {items_per_day}") # Fixed print variable here

# 4. Items per week (Items/Day * 7)
items_per_week = items_per_day * 7
print(f"Items per week: {items_per_week}")

# 5. Items per year (Items/Week * 52)
items_per_year = items_per_week * 52
print(f"Items per year: {items_per_year}")
# Out:
# Hours per day: 24
# Items per shift: 4512
# Items per day: 13536
# Items per week: 94752
# Items per year: 4927104

# %%
# Q12 - You are travelling from Nepal to UK
# Flight distance = 7000 km
# Plane speed = 850 km per hour
# Calculate flight_time in hours
# Calculate flight_time in minutes
# Calculate flight_time in seconds
# Q12 - Nepal to UK Flight Time Calculation

flight_distance = 7000   # in km
plane_speed = 850        # km per hour

# Flight time in hours
flight_time_hours = flight_distance / plane_speed

# Flight time in minutes
flight_time_minutes = flight_time_hours * 60

# Flight time in seconds
flight_time_seconds = flight_time_minutes * 60

print("Flight Time in Hours:", flight_time_hours)
print("Flight Time in Minutes:", flight_time_minutes)
print("Flight Time in Seconds:", flight_time_seconds)

# Q13 - A data science course has 7 modules
# Each module has 5 lessons
# Each lesson takes 45 minutes
# Calculate total_lessons
# Calculate total_minutes
# Calculate total_hours
# Calculate total_days (24 hours in a day)
# Q13 - Data Science Course Calculation

modules = 7
lessons_per_module = 5
lesson_time = 45   # minutes

# Total lessons
total_lessons = modules * lessons_per_module

# Total minutes
total_minutes = total_lessons * lesson_time

# Total hours
total_hours = total_minutes / 60

# Total days
total_days = total_hours / 24

print("Total Lessons:", total_lessons)
print("Total Minutes:", total_minutes)
print("Total Hours:", total_hours)
print("Total Days:", total_days)

# Q14 - Social media post goes viral
# Hour 1: 100 views
# Views double every hour
# Calculate views after 2 hours (100 * 2**1)
# Calculate views after 5 hours
# Calculate views after 10 hours
# Calculate views after 24 hours
# Q14 - Social Media Viral Views Calculation

initial_views = 100

# Views after different hours
views_after_2_hours = initial_views * 2**1
views_after_5_hours = initial_views * 2**4
views_after_10_hours = initial_views * 2**9
views_after_24_hours = initial_views * 2**23

print("Views after 2 hours:", views_after_2_hours)
print("Views after 5 hours:", views_after_5_hours)
print("Views after 10 hours:", views_after_10_hours)
print("Views after 24 hours:", views_after_24_hours)

# Q15 - UK masters tuition
# tuition_per_year = 25000 (pounds)
# living_cost_per_month = 1200
# course_duration_years = 1
# Calculate total_tuition
# Calculate total_living_cost (12 months)
# Calculate total_cost
# If scholarship = 5000 pounds
# Calculate final_cost after scholarship
# Q15 - UK Masters Cost Calculation

tuition_per_year = 25000      # pounds
living_cost_per_month = 1200
course_duration_years = 1
scholarship = 5000

# Total tuition cost
total_tuition = tuition_per_year * course_duration_years

# Total living cost for 12 months
total_living_cost = living_cost_per_month * 12

# Total overall cost
total_cost = total_tuition + total_living_cost

# Final cost after scholarship
final_cost = total_cost - scholarship

print("Total Tuition:", total_tuition)
print("Total Living Cost:", total_living_cost)
print("Total Cost:", total_cost)
print("Final Cost after Scholarship:", final_cost)
# Out:
# Flight Time in Hours: 8.235294117647058
# Flight Time in Minutes: 494.1176470588235
# Flight Time in Seconds: 29647.05882352941
# Total Lessons: 35
# Total Minutes: 1575
# Total Hours: 26.25
# Total Days: 1.09375
# Views after 2 hours: 200
# Views after 5 hours: 1600
# Views after 10 hours: 51200
# Views after 24 hours: 838860800
# Total Tuition: 25000
# Total Living Cost: 14400
# Total Cost: 39400
# Final Cost after Scholarship: 34400
