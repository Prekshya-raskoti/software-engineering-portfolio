# %%
print("Day1 - starting my big-data-foundations")
# Out:
# Day1 - starting my big-data-foundations

# %%
#print empty line
print()
print("")

# %%
name = "Prekshya Raskoti"
age = 23
print(name,age)
# Out:
# Prekshya Raskoti 23

# %%
numbers = [1,2,3,4,5]
for n in numbers:
    print(n * 3)
# Out:
# 3
# 6
# 9
# 12
# 15

# %%
def add_numbers(a,b):
    return a + b

print(add_numbers(7,4))
# Out:
# 11

# %%
print(7 - 9)
# Out:
# -2

# %%
# Division always makes float (regular division)
print(6 / 3)
# Out:
# 2.0

# %%
# this is floor division which always gives the integer
print(6 // 3)
# Out:
# 2

# %%
# modulo gives the remainder after division
print(10 % 3)
# Out:
# 1

# %%
print(2 ** 8)
# Out:
# 256

# %%
x = 4
print(type(x))
y = 4.0
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
# Creating Variables
new_var = 7 + 8
print(new_var)
# Out:
# 15

# %%
# Manipulating Variables (can change the assigned value of a variable by overriding the previous value)
my_var = 18
print(my_var)
my_var = 10
print(my_var)
# Out:
# 18
# 10

# %%
# increase the value of my_var by 3
my_var = my_var + 3
print(my_var)
# Out:
# 13
